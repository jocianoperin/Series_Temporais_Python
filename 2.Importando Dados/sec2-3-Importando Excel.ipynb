# %% [markdown]
# # Importar Arquivo Excel
# Prof. Fernando Amaral

# %%
import numpy as np
import pandas as pd
file = "boston1.xls"
x1 = pd.ExcelFile(file)
print(x1.sheet_names)

# %%
df1 = x1.parse('Sheet1')
df1.head()

# %%
df1 = x1.parse('Sheet2')
df1.head()
